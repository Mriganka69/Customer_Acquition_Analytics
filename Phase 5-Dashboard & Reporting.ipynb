# %% [markdown]
# # 📓 Phase 5: Dashboard & Reporting

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv("updated_customer_data_with_cac.csv")

# Set a clean visual style
sns.set(style="whitegrid")

# %%
# Choose a channel to filter by (change this manually)
selected_channel = 'All'  # Change to 'Email Marketing', 'Social Media', etc.

# Apply filter
if selected_channel == 'All':
    filtered_df = df.copy()
else:
    filtered_df = df[df['Marketing_Channel'] == selected_channel]

# %% [markdown]
# ## Display Summary Metrics

# %%
total_spend = filtered_df['Marketing_Spend'].sum()
total_customers = filtered_df['New_Customers'].sum()
average_cac = filtered_df['CAC'].mean()

print(f"📊 Dashboard Summary for: {selected_channel}")
print(f"----------------------------------------")
print(f"💰 Total Marketing Spend: ${total_spend:,.2f}")
print(f"👥 Total New Customers: {total_customers}")
print(f"📉 Average CAC: ${average_cac:.2f}")
# Out:
# 📊 Dashboard Summary for: All
# ----------------------------------------
# 💰 Total Marketing Spend: $1,547,363.27
# 👥 Total New Customers: 15035
# 📉 Average CAC: $125.19

# %% [markdown]
# ## Bar Chart: Average CAC by Channel

# %%
channel_cac = df.groupby("Marketing_Channel")['CAC'].mean().sort_values()

plt.figure(figsize=(8, 4))
sns.barplot(x=channel_cac.index, y=channel_cac.values, palette="Blues_d")
plt.title("Average CAC by Marketing Channel")
plt.ylabel("CAC")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# ## Scatter Plot: Spend vs New Customers

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=filtered_df, x='Marketing_Spend', y='New_Customers', hue='Marketing_Channel', palette='Set1')
plt.title("Marketing Spend vs New Customers")
plt.xlabel("Marketing Spend")
plt.ylabel("New Customers")
plt.legend(title="Channel")
plt.show()

# %% [markdown]
# ## Show Data Table

# %%
print("🔎 Filtered Data Table:")
filtered_df.head(10)  # Show top 10 rows
# Out:
# 🔎 Filtered Data Table:
#   Customer_ID Marketing_Channel  Marketing_Spend  New_Customers         CAC
# 0    CUST0001   Email Marketing      3489.027844             16  218.064240
# 1    CUST0002        Online Ads      1107.865808             33   33.571691
# 2    CUST0003      Social Media      2576.081025             44   58.547296
# 3    CUST0004        Online Ads      3257.567932             32  101.798998
# 4    CUST0005   Email Marketing      1108.408185             13   85.262168
# 5    CUST0006   Email Marketing      3570.998592             35  102.028531
# 6    CUST0007          Referral      1542.797949             27   57.140665
# 7    CUST0008        Online Ads      2846.793776             22  129.399717
# 8    CUST0009      Social Media      1201.138534             17   70.655208
# 9    CUST0010        Online Ads      2516.415457             39   64.523473
